# %%
import pandas as pd

# Загрузка данных
df = pd.read_csv('denoising_results_for_ten_pics.csv')

# Функция для нахождения лучших результатов по PSNR и SSIM для каждой картинки и типа шума
def find_best_results(df):
    results = []
    images = df['image'].unique()
    noise_types = df['noise_type'].unique()

    for image in images:
        for noise_type in noise_types:
            subset = df[(df['image'] == image) & (df['noise_type'] == noise_type)]

            # Лучший PSNR
            best_psnr = subset.loc[subset['psnr'].idxmax()]
            results.append({
                'image': image,
                'noise_type': noise_type,
                'metric': 'PSNR',
                'denoising_method': best_psnr['denoising_method'],
                'strength': best_psnr['strength'],
                'mu': best_psnr['mu'],
                'value': best_psnr['psnr'],
                'ssim': best_psnr['ssim'],
                'output_path': best_psnr['output_path']
            })

            # Лучший SSIM
            best_ssim = subset.loc[subset['ssim'].idxmax()]
            results.append({
                'image': image,
                'noise_type': noise_type,
                'metric': 'SSIM',
                'denoising_method': best_ssim['denoising_method'],
                'strength': best_ssim['strength'],
                'mu': best_ssim['mu'],
                'value': best_ssim['ssim'],
                'psnr': best_ssim['psnr'],
                'output_path': best_ssim['output_path']
            })
    results = pd.DataFrame(results)
    return results

# Получаем лучшие результаты
best_results = find_best_results(df)

# Выводим результаты
best_results[['image', 'noise_type', 'metric', 'denoising_method', 'strength', 'mu', 'value', 'ssim', 'psnr']]
# Out:
#              image   noise_type metric denoising_method  strength     mu  \
# 0   airplaneU2.bmp  salt_pepper   PSNR    Moreau-Yosida       1.0  0.010
# 1   airplaneU2.bmp  salt_pepper   SSIM    Moreau-Yosida       0.1  0.001
# 2   airplaneU2.bmp     gaussian   PSNR               TV       0.1  0.001
# 3   airplaneU2.bmp     gaussian   SSIM    Moreau-Yosida       0.6  0.006
# 4     cablecar.bmp  salt_pepper   PSNR    Moreau-Yosida       0.9  0.009
# 5     cablecar.bmp  salt_pepper   SSIM    Moreau-Yosida       0.9  0.009
# 6     cablecar.bmp     gaussian   PSNR    Moreau-Yosida       0.5  0.005
# 7     cablecar.bmp     gaussian   SSIM    Moreau-Yosida       0.5  0.005
# 8       fruits.bmp  salt_pepper   PSNR    Moreau-Yosida       0.6  0.006
# 9       fruits.bmp  salt_pepper   SSIM               TV       0.1  0.001
# 10      fruits.bmp     gaussian   PSNR    Moreau-Yosida       0.5  0.005
# 11      fruits.bmp     gaussian   SSIM    Moreau-Yosida       0.2  0.002
# 12    goldhill.bmp  salt_pepper   PSNR               TV       0.1  0.001
# 13    goldhill.bmp  salt_pepper   SSIM               TV       0.1  0.001
# 14    goldhill.bmp     gaussian   PSNR    Moreau-Yosida       0.2  0.002
# 15    goldhill.bmp     gaussian   SSIM    Moreau-Yosida       0.2  0.002
# 16    Malamute.bmp  salt_pepper   PSNR    Moreau-Yosida       0.2  0.002
# 17    Malamute.bmp  salt_pepper   SSIM    Moreau-Yosida       0.2  0.002
# 18    Malamute.bmp     gaussian   PSNR               TV       0.1  0.001
# 19    Malamute.bmp     gaussian   SSIM               TV       0.1  0.001
# 20        pens.bmp  salt_pepper   PSNR    Moreau-Yosida       0.2  0.002
# 21        pens.bmp  salt_pepper   SSIM               TV       0.1  0.001
# 22        pens.bmp     gaussian   PSNR               TV       0.1  0.001
# 23        pens.bmp     gaussian   SSIM               TV       0.1  0.001
# 24     flowers.ppm  salt_pepper   PSNR               TV       0.1  0.001
# 25     flowers.ppm  salt_pepper   SSIM               TV       0.1  0.001
# 26     flowers.ppm     gaussian   PSNR               TV       0.1  0.001
# 27     flowers.ppm     gaussian   SSIM               TV       0.1  0.001
# 28      soccer.ppm  salt_pepper   PSNR               TV       0.1  0.001
# 29      soccer.ppm  salt_pepper   SSIM               TV       0.1  0.001
# 30      soccer.ppm     gaussian   PSNR               TV       0.1  0.001
# 31      soccer.ppm     gaussian   SSIM               TV       0.1  0.001
# 32       yacht.ppm  salt_pepper   PSNR    Moreau-Yosida       0.5  0.005
# 33       yacht.ppm  salt_pepper   SSIM    Moreau-Yosida       0.5  0.005
# 34       yacht.ppm     gaussian   PSNR    Moreau-Yosida       0.3  0.003
# 35       yacht.ppm     gaussian   SSIM    Moreau-Yosida       0.3  0.003
# 36  lighthouse.pgm  salt_pepper   PSNR               TV       0.1  0.001
# 37  lighthouse.pgm  salt_pepper   SSIM               TV       0.1  0.001
# 38  lighthouse.pgm     gaussian   PSNR    Moreau-Yosida       0.1  0.001
# 39  lighthouse.pgm     gaussian   SSIM    Moreau-Yosida       0.1  0.001
#
#         value      ssim       psnr
# 0   32.512536  0.051922        NaN
# 1    0.063233       NaN  31.356267
# 2   33.373568  0.073139        NaN
# 3    0.305333       NaN  32.717407
# 4   39.175148  0.332090        NaN
# 5    0.332090       NaN  39.175148
# 6   32.700053  0.595684        NaN
# 7    0.595684       NaN  32.700053
# 8   38.865310  0.245819        NaN
# 9    0.247139       NaN  31.246946
# 10  33.691700  0.601305        NaN
# 11   0.602130       NaN  33.525404
# 12  30.114407  0.250774        NaN
# 13   0.250774       NaN  30.114407
# 14  32.106857  0.575637        NaN
# 15   0.575637       NaN  32.106857
# 16  37.938680  0.360045        NaN
# 17   0.360045       NaN  37.938680
# 18  30.289746  0.384895        NaN
# 19   0.384895       NaN  30.289746
# 20  37.680585  0.332407        NaN
# 21   0.382586       NaN  30.105622
# 22  31.140397  0.466882        NaN
# 23   0.466882       NaN  31.140397
# 24  29.924477  0.334648        NaN
# 25   0.334648       NaN  29.924477
# 26  30.392424  0.388734        NaN
# 27   0.388734       NaN  30.392424
# 28  29.380513  0.371820        NaN
# 29   0.371820       NaN  29.380513
# 30  29.677620  0.417276        NaN
# 31   0.417276       NaN  29.677620
# 32  38.387163  0.345255        NaN
# 33   0.345255       NaN  38.387163
# 34  32.576413  0.635362        NaN
# 35   0.635362       NaN  32.576413
# 36  29.779664  0.231670        NaN
# 37   0.231670       NaN  29.779664
# 38  30.850749  0.554585        NaN
# 39   0.554585       NaN  30.850749

# %%
SSIM_df = best_results[best_results['metric'] == 'SSIM']
SSIM_df
# Out:
#              image   noise_type metric denoising_method  strength     mu  \
# 1   airplaneU2.bmp  salt_pepper   SSIM    Moreau-Yosida       0.1  0.001
# 3   airplaneU2.bmp     gaussian   SSIM    Moreau-Yosida       0.6  0.006
# 5     cablecar.bmp  salt_pepper   SSIM    Moreau-Yosida       0.9  0.009
# 7     cablecar.bmp     gaussian   SSIM    Moreau-Yosida       0.5  0.005
# 9       fruits.bmp  salt_pepper   SSIM               TV       0.1  0.001
# 11      fruits.bmp     gaussian   SSIM    Moreau-Yosida       0.2  0.002
# 13    goldhill.bmp  salt_pepper   SSIM               TV       0.1  0.001
# 15    goldhill.bmp     gaussian   SSIM    Moreau-Yosida       0.2  0.002
# 17    Malamute.bmp  salt_pepper   SSIM    Moreau-Yosida       0.2  0.002
# 19    Malamute.bmp     gaussian   SSIM               TV       0.1  0.001
# 21        pens.bmp  salt_pepper   SSIM               TV       0.1  0.001
# 23        pens.bmp     gaussian   SSIM               TV       0.1  0.001
# 25     flowers.ppm  salt_pepper   SSIM               TV       0.1  0.001
# 27     flowers.ppm     gaussian   SSIM               TV       0.1  0.001
# 29      soccer.ppm  salt_pepper   SSIM               TV       0.1  0.001
# 31      soccer.ppm     gaussian   SSIM               TV       0.1  0.001
# 33       yacht.ppm  salt_pepper   SSIM    Moreau-Yosida       0.5  0.005
# 35       yacht.ppm     gaussian   SSIM    Moreau-Yosida       0.3  0.003
# 37  lighthouse.pgm  salt_pepper   SSIM               TV       0.1  0.001
# 39  lighthouse.pgm     gaussian   SSIM    Moreau-Yosida       0.1  0.001
#
#        value  ssim                                        output_path  \
# 1   0.063233   NaN  Testing2\airplaneU2_salt_pepper_s0.1_m0.001_Mo...
# 3   0.305333   NaN  Testing2\airplaneU2_gaussian_s0.6_m0.006_Morea...
# 5   0.332090   NaN  Testing2\cablecar_salt_pepper_s0.9_m0.009_More...
# 7   0.595684   NaN  Testing2\cablecar_gaussian_s0.5_m0.005_MoreauY...
# 9   0.247139   NaN     Testing2\fruits_salt_pepper_s0.1_m0.001_TV.png
# 11  0.602130   NaN  Testing2\fruits_gaussian_s0.2_m0.002_MoreauYos...
# 13  0.250774   NaN   Testing2\goldhill_salt_pepper_s0.1_m0.001_TV.png
# 15  0.575637   NaN  Testing2\goldhill_gaussian_s0.2_m0.002_MoreauY...
# 17  0.360045   NaN  Testing2\Malamute_salt_pepper_s0.2_m0.002_More...
# 19  0.384895   NaN      Testing2\Malamute_gaussian_s0.1_m0.001_TV.png
# 21  0.382586   NaN       Testing2\pens_salt_pepper_s0.1_m0.001_TV.png
# 23  0.466882   NaN          Testing2\pens_gaussian_s0.1_m0.001_TV.png
# 25  0.334648   NaN    Testing2\flowers_salt_pepper_s0.1_m0.001_TV.png
# 27  0.388734   NaN       Testing2\flowers_gaussian_s0.1_m0.001_TV.png
# 29  0.371820   NaN     Testing2\soccer_salt_pepper_s0.1_m0.001_TV.png
# 31  0.417276   NaN        Testing2\soccer_gaussian_s0.1_m0.001_TV.png
# 33  0.345255   NaN  Testing2\yacht_salt_pepper_s0.5_m0.005_MoreauY...
# 35  0.635362   NaN  Testing2\yacht_gaussian_s0.3_m0.003_MoreauYosi...
# 37  0.231670   NaN  Testing2\lighthouse_salt_pepper_s0.1_m0.001_TV...
# 39  0.554585   NaN  Testing2\lighthouse_gaussian_s0.1_m0.001_Morea...
#
#          psnr
# 1   31.356267
# 3   32.717407
# 5   39.175148
# 7   32.700053
# 9   31.246946
# 11  33.525404
# 13  30.114407
# 15  32.106857
# 17  37.938680
# 19  30.289746
# 21  30.105622
# 23  31.140397
# 25  29.924477
# 27  30.392424
# 29  29.380513
# 31  29.677620
# 33  38.387163
# 35  32.576413
# 37  29.779664
# 39  30.850749

# %%
PSNR_df = best_results[best_results['metric'] == 'PSNR']
PSNR_df
# Out:
#              image   noise_type metric denoising_method  strength     mu  \
# 0   airplaneU2.bmp  salt_pepper   PSNR    Moreau-Yosida       1.0  0.010
# 2   airplaneU2.bmp     gaussian   PSNR               TV       0.1  0.001
# 4     cablecar.bmp  salt_pepper   PSNR    Moreau-Yosida       0.9  0.009
# 6     cablecar.bmp     gaussian   PSNR    Moreau-Yosida       0.5  0.005
# 8       fruits.bmp  salt_pepper   PSNR    Moreau-Yosida       0.6  0.006
# 10      fruits.bmp     gaussian   PSNR    Moreau-Yosida       0.5  0.005
# 12    goldhill.bmp  salt_pepper   PSNR               TV       0.1  0.001
# 14    goldhill.bmp     gaussian   PSNR    Moreau-Yosida       0.2  0.002
# 16    Malamute.bmp  salt_pepper   PSNR    Moreau-Yosida       0.2  0.002
# 18    Malamute.bmp     gaussian   PSNR               TV       0.1  0.001
# 20        pens.bmp  salt_pepper   PSNR    Moreau-Yosida       0.2  0.002
# 22        pens.bmp     gaussian   PSNR               TV       0.1  0.001
# 24     flowers.ppm  salt_pepper   PSNR               TV       0.1  0.001
# 26     flowers.ppm     gaussian   PSNR               TV       0.1  0.001
# 28      soccer.ppm  salt_pepper   PSNR               TV       0.1  0.001
# 30      soccer.ppm     gaussian   PSNR               TV       0.1  0.001
# 32       yacht.ppm  salt_pepper   PSNR    Moreau-Yosida       0.5  0.005
# 34       yacht.ppm     gaussian   PSNR    Moreau-Yosida       0.3  0.003
# 36  lighthouse.pgm  salt_pepper   PSNR               TV       0.1  0.001
# 38  lighthouse.pgm     gaussian   PSNR    Moreau-Yosida       0.1  0.001
#
#         value      ssim                                        output_path  \
# 0   32.512536  0.051922  Testing2\airplaneU2_salt_pepper_s1.0_m0.010_Mo...
# 2   33.373568  0.073139    Testing2\airplaneU2_gaussian_s0.1_m0.001_TV.png
# 4   39.175148  0.332090  Testing2\cablecar_salt_pepper_s0.9_m0.009_More...
# 6   32.700053  0.595684  Testing2\cablecar_gaussian_s0.5_m0.005_MoreauY...
# 8   38.865310  0.245819  Testing2\fruits_salt_pepper_s0.6_m0.006_Moreau...
# 10  33.691700  0.601305  Testing2\fruits_gaussian_s0.5_m0.005_MoreauYos...
# 12  30.114407  0.250774   Testing2\goldhill_salt_pepper_s0.1_m0.001_TV.png
# 14  32.106857  0.575637  Testing2\goldhill_gaussian_s0.2_m0.002_MoreauY...
# 16  37.938680  0.360045  Testing2\Malamute_salt_pepper_s0.2_m0.002_More...
# 18  30.289746  0.384895      Testing2\Malamute_gaussian_s0.1_m0.001_TV.png
# 20  37.680585  0.332407  Testing2\pens_salt_pepper_s0.2_m0.002_MoreauYo...
# 22  31.140397  0.466882          Testing2\pens_gaussian_s0.1_m0.001_TV.png
# 24  29.924477  0.334648    Testing2\flowers_salt_pepper_s0.1_m0.001_TV.png
# 26  30.392424  0.388734       Testing2\flowers_gaussian_s0.1_m0.001_TV.png
# 28  29.380513  0.371820     Testing2\soccer_salt_pepper_s0.1_m0.001_TV.png
# 30  29.677620  0.417276        Testing2\soccer_gaussian_s0.1_m0.001_TV.png
# 32  38.387163  0.345255  Testing2\yacht_salt_pepper_s0.5_m0.005_MoreauY...
# 34  32.576413  0.635362  Testing2\yacht_gaussian_s0.3_m0.003_MoreauYosi...
# 36  29.779664  0.231670  Testing2\lighthouse_salt_pepper_s0.1_m0.001_TV...
# 38  30.850749  0.554585  Testing2\lighthouse_gaussian_s0.1_m0.001_Morea...
#
#     psnr
# 0    NaN
# 2    NaN
# 4    NaN
# 6    NaN
# 8    NaN
# 10   NaN
# 12   NaN
# 14   NaN
# 16   NaN
# 18   NaN
# 20   NaN
# 22   NaN
# 24   NaN
# 26   NaN
# 28   NaN
# 30   NaN
# 32   NaN
# 34   NaN
# 36   NaN
# 38   NaN
